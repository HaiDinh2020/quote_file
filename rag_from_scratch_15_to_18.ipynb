# %% [markdown]
# # Rag From Scratch: Retrieval
#
# ![Screenshot 2024-03-25 at 8.23.58 PM.png](attachment:c6ee3569-ca87-49b5-8f2c-21193230f8d4.png)

# %% [markdown]
# ## Enviornment
#
# `(1) Packages`

# %%
! pip install langchain_community tiktoken langchain-openai langchainhub chromadb langchain cohere langchain-google-genai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 7.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 48.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 63.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 628.3/628.3 kB 48.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 92.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 64.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.9/249.9 kB 25.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.6/278.6 kB 29.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# `(2) LangSmith`
#
# https://docs.smith.langchain.com/

# %%
# !pip install --quiet langchain_experimental
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.0/209.0 kB 4.9 MB/s eta 0:00:00

# %%
import os
os.environ['LANGCHAIN_TRACING_V2'] = 'true'
os.environ['LANGCHAIN_ENDPOINT'] = 'https://api.smith.langchain.com'
os.environ['LANGCHAIN_API_KEY'] = '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'
os.environ['LANGCHAIN_PROJECT'] ="pr-roasted-publisher-71"

# %% [markdown]
# `(3) API Keys`

# %%
os.environ["GOOGLE_API_KEY"] = "AIzaSyAx5ImP844PsNMCgTkw16prMU49lFZw5HM"
os.environ['COHERE_API_KEY'] = "yRvfpEV7Xq6cr6VQ4HbBr87lbzerqXHoI2j2IAHU"

# %% [markdown]
# ## Part 15: Re-ranking
#
# We showed this previously with RAG-fusion.
#
# ![Screenshot 2024-03-25 at 2.59.21 PM.png](attachment:f0d70de3-4427-4849-a35f-92ab0e5e91cf.png)

# %%
from langchain.document_loaders import TextLoader
import os
from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAIEmbeddings

docs = []
for file_name in os.listdir("/content/data"):
    if file_name.endswith(".txt"):
        print(file_name)
        loader = TextLoader(f"/content/data/{file_name}")
        docs.extend(loader.load())

docs_as_string = "\n".join([doc.page_content for doc in docs])
print(docs[0].page_content[:1000])
# Out:
# HDSD_Vai_tro_Đang_vien.txt
# Dieu_le_DCSVN.txt
# Van_kien_Dai_hoi_XIII_tap_1.txt
# HDSD_Vai_tro_Bi_thu_Pho_bi_thu_Thư_ky_Đang_bo.txt
# HDSD_Vai_tro_Bi_thu_Pho_bi_thu_Thu_ky_Chi_bo.txt
# DỰ ÁN: SỔ TAY ĐẢNG VIÊN ĐIỆN TỬ
# TÀI LIỆU HƯỚNG DẪN SỬ DỤNG
# Mã số:
# UM/0.3
# Phiên bản:
# 0.3
# Ngày hiệu lực:
# 07/09/2022
# Họ và tên
# Chức danh
# Ngày, tháng
# Ký tên
# Soạn thảo
# Nguyễn Thu Thảo
# BA
# 07/09/2022
# Xem xét
# Nguyễn Hồng Anh Tấn
# Sub-PO
# 07/09/2022
# Thẩm định
# Ngô Việt Dũng
# Tech Lead
# 07/09/2022
# Phê chuẩn
# Ngô Quốc Dũng
# PM
# 07/09/2022
# LỊCH SỬ THAY ĐỔI
# ID
# Phiên bản
# Người thực hiện
# Người phê duyệt
# Ngày hiệu lực
# Nội dung thay đổi
# 280522
# 0.1
# Nguyễn Thu Thảo
# Ngô Quốc Dũng
# 28/05/2022
# Tạo mới
# 050622
# 0.2
# Nguyễn Thu Thảo
# Ngô Quốc Dũng
# 05/06/2022
# - Thêm đường link tải app trên iOS & Android
# - Thêm nội dung quy ước đánh máy
# - Thêm phụ lục
# - Thêm chú thích và hình ảnh
# 070922
# 0.3
# Nguyễn Thu Thảo
# Nguyễn Việt Dũng
# ...

# %%
#### INDEXING ####

from langchain.document_loaders import TextLoader
import os
from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAIEmbeddings

docs = []
for file_name in os.listdir("/content/data"):
    if file_name.endswith(".txt"):
        print(file_name)
        loader = TextLoader(f"/content/data/{file_name}")
        docs.extend(loader.load())

docs_as_string = "\n".join([doc.page_content for doc in docs])

# blog_docs = loader.load()

# Split
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_experimental.text_splitter import SemanticChunker

# text_splitter_1 = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
#     chunk_size=300,
#     chunk_overlap=50)

text_splitter = SemanticChunker(GoogleGenerativeAIEmbeddings(model="models/embedding-001"))
# Make splits
# splits_1 = text_splitter_1.split_documents(docs)
splits = text_splitter.create_documents([docs_as_string])
filtered_splits = [doc for doc in splits if len(doc.page_content.split()) >= 10]
print(filtered_splits)
print(len(splits))
print(len(filtered_splits))
# Index

from langchain_openai import OpenAIEmbeddings
# from langchain_cohere import CohereEmbeddings
from langchain_community.vectorstores import Chroma
vectorstore = Chroma.from_documents(documents=filtered_splits,
                                    # embedding=CohereEmbeddings()
                                    # embedding=OpenAIEmbeddings())
                                    embedding=GoogleGenerativeAIEmbeddings(model="models/embedding-001"))


retriever = vectorstore.as_retriever()
# Out:
# HDSD_Vai_tro_Đang_vien.txt
# Dieu_le_DCSVN.txt
# Van_kien_Dai_hoi_XIII_tap_1.txt
# HDSD_Vai_tro_Bi_thu_Pho_bi_thu_Thư_ky_Đang_bo.txt
# HDSD_Vai_tro_Bi_thu_Pho_bi_thu_Thu_ky_Chi_bo.txt
# ...

# %%
from langchain.prompts import ChatPromptTemplate

# RAG-Fusion
template = """Bạn là một trợ lý hữu ích tạo ra nhiều truy vấn tìm kiếm dựa trên một truy vấn đầu vào. \n
Tạo nhiều truy vấn tìm kiếm liên quan đến hướng dẫn sử dụng hệ thống sổ tay đảng viên, văn kiện, điều lệ đảng: {question} \n
Output (4 queries):"""
prompt_rag_fusion = ChatPromptTemplate.from_template(template)

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI

generate_queries = (
    prompt_rag_fusion
    | ChatGoogleGenerativeAI(model="gemini-1.5-flash", temperature=0)
    | StrOutputParser()
    | (lambda x: x.split("\n"))
)

print(generate_queries)
# Out:
# first=ChatPromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, template='Bạn là một trợ lý hữu ích tạo ra nhiều truy vấn tìm kiếm dựa trên một truy vấn đầu vào. \n\nTạo nhiều truy vấn tìm kiếm liên quan đến hướng dẫn sử dụng hệ thống sổ tay đảng viên, văn kiện, điều lệ đảng: {question} \n\nOutput (4 queries):'), additional_kwargs={})]) middle=[ChatGoogleGenerativeAI(model='models/gemini-1.5-flash', google_api_key=SecretStr('**********'), temperature=0.0, client=<google.ai.generativelanguage_v1beta.services.generative_service.client.GenerativeServiceClient object at 0x7e7361604160>, default_metadata=()), StrOutputParser()] last=RunnableLambda(...)

# %%
from langchain.load import dumps, loads

def reciprocal_rank_fusion(results: list[list], k=60):
    """ Reciprocal_rank_fusion that takes multiple lists of ranked documents
        and an optional parameter k used in the RRF formula """

    # Initialize a dictionary to hold fused scores for each unique document
    fused_scores = {}

    # Iterate through each list of ranked documents
    for docs in results:
        # Iterate through each document in the list, with its rank (position in the list)
        for rank, doc in enumerate(docs):
            # Convert the document to a string format to use as a key (assumes documents can be serialized to JSON)
            doc_str = dumps(doc)
            # If the document is not yet in the fused_scores dictionary, add it with an initial score of 0
            if doc_str not in fused_scores:
                fused_scores[doc_str] = 0
            # Retrieve the current score of the document, if any
            previous_score = fused_scores[doc_str]
            # Update the score of the document using the RRF formula: 1 / (rank + k)
            fused_scores[doc_str] += 1 / (rank + k)

    # Sort the documents based on their fused scores in descending order to get the final reranked results
    reranked_results = [
        (loads(doc), score)
        for doc, score in sorted(fused_scores.items(), key=lambda x: x[1], reverse=True)
    ]

    # Return the reranked results as a list of tuples, each containing the document and its fused score
    return reranked_results

question = "Cách tạo mới thông báo?"
retrieval_chain_rag_fusion = generate_queries | retriever.map() | reciprocal_rank_fusion
docs = retrieval_chain_rag_fusion.invoke({"question": question})
len(docs)
# Out:
# 6

# %%
from operator import itemgetter
from langchain_core.runnables import RunnablePassthrough

# RAG
template = """Trả lời câu hỏi sau dựa trên ngữ cảnh này:

{context}

Question: {question}
"""

prompt = ChatPromptTemplate.from_template(template)

llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash", temperature=0)

final_rag_chain = (
    {"context": retrieval_chain_rag_fusion,
     "question": itemgetter("question")}
    | prompt
    | llm
    | StrOutputParser()
)

final_rag_chain.invoke({"question":question})
# Out:
# 'Không thể trả lời câu hỏi "Cách tạo mới thông báo?" dựa trên ngữ cảnh đã cho.  Ngữ cảnh chỉ chứa các cặp (Document, số), dường như liên quan đến phân tích văn bản hoặc xử lý ngôn ngữ tự nhiên, nhưng không cung cấp bất kỳ thông tin nào về cách tạo thông báo.\n'

# %% [markdown]
# We can also use [Cohere Re-Rank](https://python.langchain.com/docs/integrations/retrievers/cohere-reranker#doing-reranking-with-coherererank).
#
# See [here](https://txt.cohere.com/rerank/):
#
# ![data-src-image-387e0861-93de-4823-84e0-7ae04f2be893.png](attachment:f46d29d0-e1a2-4c09-8b65-d7f5b675209d.png)

# %%
from langchain_community.llms import Cohere
from langchain.retrievers import  ContextualCompressionRetriever
from langchain.retrievers.document_compressors import CohereRerank

# %%
from langchain.retrievers.document_compressors import CohereRerank

retriever = vectorstore.as_retriever(search_kwargs={"k": 10})

# Re-rank
compressor = CohereRerank()
compression_retriever = ContextualCompressionRetriever(
    base_compressor=compressor, base_retriever=retriever
)

compressed_docs = compression_retriever.get_relevant_documents(question)

# %% [markdown]
# ## 16 - Retrieval (CRAG)
#
# `Deep Dive`
#
# https://www.youtube.com/watch?v=E2shqsYwxck
#
# `Notebooks`
#
# https://github.com/langchain-ai/langgraph/blob/main/examples/rag/langgraph_crag.ipynb
#
# https://github.com/langchain-ai/langgraph/blob/main/examples/rag/langgraph_crag_mistral.ipynb

# %% [markdown]
# # Generation
#
#
#
# ## 17 - Retrieval (Self-RAG)
#
# `Notebooks`
#
# https://github.com/langchain-ai/langgraph/tree/main/examples/rag
#
# https://github.com/langchain-ai/langgraph/blob/main/examples/rag/langgraph_self_rag_mistral_nomic.ipynb

# %% [markdown]
# ## 18 - Impact of long context
#
# `Deep dive`
#
# https://www.youtube.com/watch?v=SsHUNfhF32s
#
# `Slides`
#
# https://docs.google.com/presentation/d/1mJUiPBdtf58NfuSEQ7pVSEQ2Oqmek7F1i4gBwR6JDss/edit#slide=id.g26c0cb8dc66_0_0
